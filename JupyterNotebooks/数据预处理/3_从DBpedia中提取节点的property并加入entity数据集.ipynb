# %%
import re
import numpy as np
import pandas as pd
from unidecode import unidecode

# %% [markdown]
# ## Person Data

# %%
# 从txt中获取数据并查看长度
person = []
for line in open('persondata_en.txt', "r",encoding='UTF-8'):
    person.append(line)
len(person)
# Out:
# 6067248

# %%
# 删除首尾行
person_data = person[1:6067247]

# %%
property1 = []
for j in person_data:
    # 不提取type行
    if 'type' in j:
        continue
    # 避免其他语言文字，全部换成英文
    j = unidecode(j)
    # 找到所有网址，删除最后一个
    last = re.findall('<http://.*?> ',j)
    j = j.replace(last[-1],'')
    # 正则提取三元组
    if '> \"' in j:
        result1 = re.findall('/[^/#]*>',j) #提取所有/>中除了/的字符
        result2 = re.findall('\".+\"',j) # 提取双引号中的内容
        property1.append(result1+result2)

# %%
# property放入dataframe
df1 = pd.DataFrame(property1, columns = ['node_name', 'property_name', 'property_content'])
print(len(df1))
df1.head()
# Out:
# 4381695
#                   node_name  property_name                  property_content
# 0  /Ibrahim_Pasha_of_Egypt>         /name>                   "Ibrahim Pasha"
# 1  /Ibrahim_Pasha_of_Egypt>  /description>  "Ottoman politician and general"
# 2  /Ibrahim_Pasha_of_Egypt>    /birthDate>                            "1789"
# 3  /Ibrahim_Pasha_of_Egypt>    /deathDate>                      "1848-11-10"
# 4          /Poul_Kjaerholm>         /name>                  "Poul Kjaerholm"

# %%
# 删除多余的符号
df1['node_name'] = df1['node_name'].str.replace('[/>]+', '')
df1['node_name'] = df1['node_name'].str.replace('_+', ' ')

df1['property_name'] = df1['property_name'].str.replace('[/>#]+', '')

df1['property_content'] = df1['property_content'].str.replace('[/>\"\"]+', '')
df1['property_content'] = df1['property_content'].str.replace('_+', ' ')
df1.head()
# Out:
#                 node_name property_name                property_content
# 0  Ibrahim Pasha of Egypt          name                   Ibrahim Pasha
# 1  Ibrahim Pasha of Egypt   description  Ottoman politician and general
# 2  Ibrahim Pasha of Egypt     birthDate                            1789
# 3  Ibrahim Pasha of Egypt     deathDate                      1848-11-10
# 4          Poul Kjaerholm          name                  Poul Kjaerholm

# %%
#查看df1中有哪些是空的
def find_all_index(arr,item):
    return [i for i,a in enumerate(arr) if a==item]
find_all_index(df1['property_content'], '')
# Out:
# []

# %%
print(len(df1))
df1 = df1.dropna()
print(len(df1))
# Out:
# 4381695
# 4381692

# %% [markdown]
# ## Mapping Literals Object

# %%
# 从txt中获取数据并查看长度
literals = []
for line in open('mappingbased_literals_en.txt', "r",encoding='UTF-8'):
    literals.append(line)
len(literals)
# Out:
# 16897943

# %%
literals = literals[1:16897942]

# %%
property2 = []
for j in literals:
    # 避免其他语言文字，全部换成英文
    j = unidecode(j)
    # 找到所有网址，删除最后一个
    last = re.findall('<http://.*?> ',j)
    if len(last) == 4:
        j = j.replace(last[-1],'')
        j = j.replace(last[-2],'')
    else:
        j = j.replace(last[-1],'')
    # 正则提取三元组
    if '> \"' in j:
        result1 = re.findall('/[^/]+>',j) #提取所有/>中除了/的字符
        result2 = re.findall('\".+\"',j) # 提取双引号中的内容
        property2.append(result1+result2)

# %%
# property放入dataframe
df2 = pd.DataFrame(property2, columns = ['node_name', 'property_name', 'property_content','others'])
print(len(df2))
df2.head()
# Out:
# 16897941
#            node_name    property_name property_content others
# 0          /Actrius>           /name>      "Actresses"   None
# 1          /Actrius>        /runtime>         "6000.0"   None
# 2  /Animalia_(book)>           /name>       "Animalia"   None
# 3  /Animalia_(book)>  /numberOfPages>             "32"   None
# 4  /Animalia_(book)>           /isbn>  "0-810-91868-4"   None

# %%
df2 = df2.drop('others', axis = 1)

# %%
df2
# Out:
#                   node_name    property_name          property_content
# 0                 /Actrius>           /name>               "Actresses"
# 1                 /Actrius>        /runtime>                  "6000.0"
# 2         /Animalia_(book)>           /name>                "Animalia"
# 3         /Animalia_(book)>  /numberOfPages>                      "32"
# 4         /Animalia_(book)>           /isbn>           "0-810-91868-4"
# ...                     ...              ...                       ...
# 16897936   /Miles_Byass__8>  /numberOfGoals>                       "4"
# 16897937   /Miles_Byass__9>          /years>                    "2009"
# 16897938      /Miles_Byass>           /name>            "Byass, Miles"
# 16897939      /Miles_Byass>      /birthYear>                    "1991"
# 16897940      /Miles_Byass>    /description>  "American soccer player"
#
# [16897941 rows x 3 columns]

# %%
# 删除多余的符号
df2['node_name'] = df2['node_name'].str.replace('[/>]+', '')
df2['node_name'] = df2['node_name'].str.replace('[_\|]+', ' ')
df2['node_name'] = df2['node_name'].str.replace('%22', '')

df2['property_name'] = df2['property_name'].str.replace('[/>]+', '')
df2['property_name'] = df2['property_name'].str.replace('[#]+', ' ')

df2['property_content'] = df2['property_content'].str.replace('[/>\"\"]+', '')
df2['property_content'] = df2['property_content'].str.replace('[_\|]+', ' ')
df2.head()
# Out:
#          node_name  property_name property_content
# 0          Actrius           name        Actresses
# 1          Actrius        runtime           6000.0
# 2  Animalia (book)           name         Animalia
# 3  Animalia (book)  numberOfPages               32
# 4  Animalia (book)           isbn    0-810-91868-4

# %%
len(find_all_index(df2['property_content'], None))
# Out:
# 105

# %%
print(len(df2))
df2 = df2.dropna()
print(len(df2))
# Out:
# 16897941
# 16897836

# %%
find_all_index(df2['node_name'], '')
# Out:
# []

# %% [markdown]
# ## Combination

# %%
# 合并以上两个dataframe
# 去重
# 转换格式{"":""}
# 作为字典
# 导入entit_new.csv
# 加一列property

# %%
df3 = pd.concat([df1,df2], axis=0)

# %%
df3
# Out:
#                        node_name  property_name  \
# 0         Ibrahim Pasha of Egypt           name
# 1         Ibrahim Pasha of Egypt    description
# 2         Ibrahim Pasha of Egypt      birthDate
# 3         Ibrahim Pasha of Egypt      deathDate
# 4                 Poul Kjaerholm           name
# ...                          ...            ...
# 16897936           Miles Byass 8  numberOfGoals
# 16897937           Miles Byass 9          years
# 16897938             Miles Byass           name
# 16897939             Miles Byass      birthYear
# 16897940             Miles Byass    description
#
#                         property_content
# 0                          Ibrahim Pasha
# 1         Ottoman politician and general
# 2                                   1789
# 3                             1848-11-10
# 4                         Poul Kjaerholm
# ...                                  ...
# 16897936                               4
# 16897937                            2009
# 16897938                    Byass, Miles
# 16897939                            1991
# 16897940          American soccer player
#
# [21279528 rows x 3 columns]

# %%
df3 = df3.drop_duplicates()
df3
# Out:
#                        node_name    property_name  \
# 0         Ibrahim Pasha of Egypt             name
# 1         Ibrahim Pasha of Egypt      description
# 2         Ibrahim Pasha of Egypt        birthDate
# 3         Ibrahim Pasha of Egypt        deathDate
# 4                 Poul Kjaerholm             name
# ...                          ...              ...
# 16897935           Miles Byass 8  numberOfMatches
# 16897936           Miles Byass 8    numberOfGoals
# 16897937           Miles Byass 9            years
# 16897938             Miles Byass             name
# 16897939             Miles Byass        birthYear
#
#                         property_content
# 0                          Ibrahim Pasha
# 1         Ottoman politician and general
# 2                                   1789
# 3                             1848-11-10
# 4                         Poul Kjaerholm
# ...                                  ...
# 16897935                              22
# 16897936                               4
# 16897937                            2009
# 16897938                    Byass, Miles
# 16897939                            1991
#
# [19259891 rows x 3 columns]

# %%
df3['property'] = '\''+df3['property_name']+'\': '+'\''+df3['property_content']+'\''
df_test = df3
# Out:
# C:\hongyu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test = df_test.drop('property_name', axis = 1)
df_test = df_test.drop('property_content', axis = 1)
df_test
# Out:
#                        node_name  \
# 0         Ibrahim Pasha of Egypt
# 1         Ibrahim Pasha of Egypt
# 2         Ibrahim Pasha of Egypt
# 3         Ibrahim Pasha of Egypt
# 4                 Poul Kjaerholm
# ...                          ...
# 16897935           Miles Byass 8
# 16897936           Miles Byass 8
# 16897937           Miles Byass 9
# 16897938             Miles Byass
# 16897939             Miles Byass
#
#                                                  property
# 0                                 'name': 'Ibrahim Pasha'
# 1         'description': 'Ottoman politician and general'
# 2                                     'birthDate': '1789'
# 3                               'deathDate': '1848-11-10'
# 4                                'name': 'Poul Kjaerholm'
# ...                                                   ...
# 16897935                          'numberOfMatches': '22'
# 16897936                             'numberOfGoals': '4'
# 16897937                                  'years': '2009'
# 16897938                           'name': 'Byass, Miles'
# 16897939                              'birthYear': '1991'
#
# [19259891 rows x 2 columns]

# %%
def ab(df):
    return','.join(df.values)
    
df_test_1 = df_test.groupby(['node_name'])['property'].apply(ab)
df_test_1
# Out:
# node_name
#  '12' Four 1                   'name': 'Triumph Gloria('12'  '12') Four','con...
#  '73.                                         'name': 'Najveci uspjesi '68.'73.'
#  (Santigold album)             'name': '99C','releaseDate': '2016-02-26','run...
#  1                             'filename': 'Mary-marry-merry.ogg','title': 'M...
#  10                                                             'type': 'speech'
#                                                      ...
# x Sophrolaeliocattleya                          'name': 'x Sophrolaeliocattleya'
# x Sorbaronia mitschurinii                    'name': 'x Sorbaronia mitschurinii'
# x Trichocidium                                          'name': 'x Trichocidium'
# zidovudine                     'casNumber': '364057-50-1','atcPrefix': 'J05',...
# zinc superoxide dismutase 1                                   'symbol': 'Sod Cu'
# Name: property, Length: 4693764, dtype: object

# %%
df_test2 = pd.DataFrame(df_test_1)

# %%
df_test2
# Out:
#                                                                       property
# node_name
#  '12' Four 1                 'name': 'Triumph Gloria('12'  '12') Four','con...
#  '73.                                       'name': 'Najveci uspjesi '68.'73.'
#  (Santigold album)           'name': '99C','releaseDate': '2016-02-26','run...
#  1                           'filename': 'Mary-marry-merry.ogg','title': 'M...
#  10                                                           'type': 'speech'
# ...                                                                        ...
# x Sophrolaeliocattleya                        'name': 'x Sophrolaeliocattleya'
# x Sorbaronia mitschurinii                  'name': 'x Sorbaronia mitschurinii'
# x Trichocidium                                        'name': 'x Trichocidium'
# zidovudine                   'casNumber': '364057-50-1','atcPrefix': 'J05',...
# zinc superoxide dismutase 1                                 'symbol': 'Sod Cu'
#
# [4693764 rows x 1 columns]

# %%
df_test_3 = pd.DataFrame(zip(df_test2.index,df_test2['property']),columns = ['name','property'])
df_test_3
# Out:
#                                 name  \
# 0                        '12' Four 1
# 1                               '73.
# 2                  (Santigold album)
# 3                                  1
# 4                                 10
# ...                              ...
# 4693759       x Sophrolaeliocattleya
# 4693760    x Sorbaronia mitschurinii
# 4693761               x Trichocidium
# 4693762                   zidovudine
# 4693763  zinc superoxide dismutase 1
#
#                                                   property
# 0        'name': 'Triumph Gloria('12'  '12') Four','con...
# 1                       'name': 'Najveci uspjesi '68.'73.'
# 2        'name': '99C','releaseDate': '2016-02-26','run...
# 3        'filename': 'Mary-marry-merry.ogg','title': 'M...
# 4                                         'type': 'speech'
# ...                                                    ...
# 4693759                   'name': 'x Sophrolaeliocattleya'
# 4693760                'name': 'x Sorbaronia mitschurinii'
# 4693761                           'name': 'x Trichocidium'
# 4693762  'casNumber': '364057-50-1','atcPrefix': 'J05',...
# 4693763                                 'symbol': 'Sod Cu'
#
# [4693764 rows x 2 columns]

# %%
df_test_3['property'] = df_test_3['property'].str.replace('[\']+', '')

# %%
df_test_3['property'] = df_test_3['property'].str.replace(',', ', ')
df_test_3['property'] = df_test_3['property'].str.replace('\\', '')
df_test_3
# Out:
#                                 name  \
# 0                        '12' Four 1
# 1                               '73.
# 2                  (Santigold album)
# 3                                  1
# 4                                 10
# ...                              ...
# 4693759       x Sophrolaeliocattleya
# 4693760    x Sorbaronia mitschurinii
# 4693761               x Trichocidium
# 4693762                   zidovudine
# 4693763  zinc superoxide dismutase 1
#
#                                                   property
# 0        name: Triumph Gloria(12  12) Four,  configurat...
# 1                             name: Najveci uspjesi 68.73.
# 2        name: 99C,  releaseDate: 2016-02-26,  runtime:...
# 3        filename: Mary-marry-merry.ogg,  title: Mary-m...
# 4                                             type: speech
# ...                                                    ...
# 4693759                       name: x Sophrolaeliocattleya
# 4693760                    name: x Sorbaronia mitschurinii
# 4693761                               name: x Trichocidium
# 4693762  casNumber: 364057-50-1,  atcPrefix: J05,  atcS...
# 4693763                                     symbol: Sod Cu
#
# [4693764 rows x 2 columns]

# %%
pro_dict = df_test_3.set_index('name')['property'].to_dict()

# %%
entity = pd.read_csv('entity.csv',encoding = 'utf-8')
entity
# Out:
#          Unnamed: 0                                    entityName  entityId:ID
# 0                 1  Iraqi parliamentary election, September 1954            0
# 1                 2                                 New Road Team            1
# 2                 3        Here Comes Trouble (Bad Company album)            2
# 3                 4                                  Canna glauca            3
# 4                 5                                  Povla Frijsh            4
# ...             ...                                           ...          ...
# 5822928     5822929                 German submarine U-133 (1941)      5822928
# 5822929     5822930                         Rengarajan Jaiprakash      5822929
# 5822930     5822931                               Jean d'Eaubonne      5822930
# 5822931     5822932          Jack Price (footballer, born 1877) 2      5822931
# 5822932     5822933                  William Godolphin (Royalist)      5822932
#
# [5822933 rows x 3 columns]

# %%
entity = entity.drop('Unnamed: 0', axis = 1)
entity['entityProperty'] = entity['entityName']
entity['entityProperty'] = entity['entityProperty'].map(pro_dict)

# %%
entity
# Out:
#                                            entityName  entityId:ID  \
# 0        Iraqi parliamentary election, September 1954            0
# 1                                       New Road Team            1
# 2              Here Comes Trouble (Bad Company album)            2
# 3                                        Canna glauca            3
# 4                                        Povla Frijsh            4
# ...                                               ...          ...
# 5822928                 German submarine U-133 (1941)      5822928
# 5822929                         Rengarajan Jaiprakash      5822929
# 5822930                               Jean d'Eaubonne      5822930
# 5822931          Jack Price (footballer, born 1877) 2      5822931
# 5822932                  William Godolphin (Royalist)      5822932
#
#                                             entityProperty
# 0        title: Iraqi parliamentary election,   Septemb...
# 1        name: New Road,  name: New Road Team,  nick: N...
# 2        name: Here Comes Trouble,  releaseDate: 1992-0...
# 3        synonym: * Canna angustifolia (L.),  synonym: ...
# 4        name: Povla Frijsh,  surname: Frijsh,  givenNa...
# ...                                                    ...
# 5822928  name: U-133,  orderDate: 1939-08-07,  layingDo...
# 5822929  name: Jaiprakash Rengarajan,  description: Ind...
# 5822930  name: Jean d Eaubonne,  surname: Eaubonne,  gi...
# 5822931  years: 1897,  numberOfMatches: 1,  numberOfGoa...
# 5822932  name: William Godolphin,  surname: Godolphin, ...
#
# [5822933 rows x 3 columns]

# %%
# 一共5866138entity
# 有1175037 没有匹配到property
entity = entity[entity['entityProperty'].notnull()]

# %%
entity.to_csv('entity.csv')
